# %%
'''Required packages'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

'''Shows plots in the notebook without having to call plt.show()'''
# %matplotlib inline

# %% [markdown]
# Using the pandas read_csv() method, read the GDP dataset into your notebook as a DataFrame called gdp_df. Take a look at the first 6 rows.
#
# Repeat for the internet use dataset. Call this DataFrame internet_df. Take a look at the first six rows.

# %%
gdp_df = pd.read_csv("data/gdp_percapita.csv", nrows = 6606)

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2018  2190.240321              NaN
# 1     Afghanistan  2017  2202.570851              NaN
# 2     Afghanistan  2016  2200.764487              NaN
# 3     Afghanistan  2015  2212.750899              NaN
# 4     Afghanistan  2014  2249.253738              NaN
# 5     Afghanistan  2013  2264.317575              NaN

# %% [markdown]
# Repeat for the internet use dataset. Call this DataFrame internet_df. Take a look at the first six rows.

# %%
internet_df = pd.read_csv("data/internet_use.csv", nrows= 4495)

# %%
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %% [markdown]
# 7. Look at the shape of each DataFrame - how many rows? How many columns?

# %%
shape_gdp = gdp_df.shape
shape_int = internet_df.shape

print(shape_gdp)
print(shape_int)
# Out:
# (6606, 4)
# (4495, 4)

# %% [markdown]
# 8. Take a look at the datatypes for the columns in each DataFrame.

# %%
type_gdp = gdp_df.dtypes
type_int = internet_df.dtypes

print(type_gdp)
print("----------------------------------------------------------")
print(type_int)
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object
# ----------------------------------------------------------
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# 9. Take a look at the last 10 rows of each DataFrame in turn.

# %%
last_ten_gdp = gdp_df.iloc[-10:]
last_ten_gdp
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6596        Zimbabwe  1999  3600.849291              NaN
# 6597        Zimbabwe  1998  3653.920016              NaN
# 6598        Zimbabwe  1997  3580.048793              NaN
# 6599        Zimbabwe  1996  3520.430146              NaN
# 6600        Zimbabwe  1995  3226.413930              NaN
# 6601        Zimbabwe  1994  3263.934978              NaN
# 6602        Zimbabwe  1993  3033.504852              NaN
# 6603        Zimbabwe  1992  3054.889178              NaN
# 6604        Zimbabwe  1991  3426.598094              NaN
# 6605        Zimbabwe  1990  3324.348171              NaN

# %%
tail_gdp = gdp_df.tail(10)
tail_gdp
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6596        Zimbabwe  1999  3600.849291              NaN
# 6597        Zimbabwe  1998  3653.920016              NaN
# 6598        Zimbabwe  1997  3580.048793              NaN
# 6599        Zimbabwe  1996  3520.430146              NaN
# 6600        Zimbabwe  1995  3226.413930              NaN
# 6601        Zimbabwe  1994  3263.934978              NaN
# 6602        Zimbabwe  1993  3033.504852              NaN
# 6603        Zimbabwe  1992  3054.889178              NaN
# 6604        Zimbabwe  1991  3426.598094              NaN
# 6605        Zimbabwe  1990  3324.348171              NaN

# %%
last_ten_int = internet_df.iloc[-10:]
last_ten_int
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %% [markdown]
# 10. Drop the value footnotes column from both DataFrames. Check that this worked as expected.

# %%
gdp_df = gdp_df.drop(columns=['Value Footnotes'])

gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2018  2190.240321
# 1        Afghanistan  2017  2202.570851
# 2        Afghanistan  2016  2200.764487
# 3        Afghanistan  2015  2212.750899
# 4        Afghanistan  2014  2249.253738
# ...              ...   ...          ...
# 6601        Zimbabwe  1994  3263.934978
# 6602        Zimbabwe  1993  3033.504852
# 6603        Zimbabwe  1992  3054.889178
# 6604        Zimbabwe  1991  3426.598094
# 6605        Zimbabwe  1990  3324.348171
#
# [6606 rows x 3 columns]

# %%
internet_df = internet_df.drop(columns=['Value Footnotes'])

internet_df
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# 11. Change the columns for the GDP Per Capita DataFrame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’.

# %%
gdp_df = gdp_df.rename(columns={'Country or Area': 'Country','Year':'Year', 'Value':'GDP_Per_Capita'})

gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2018     2190.240321
# 1     Afghanistan  2017     2202.570851
# 2     Afghanistan  2016     2200.764487
# 3     Afghanistan  2015     2212.750899
# 4     Afghanistan  2014     2249.253738
# ...           ...   ...             ...
# 6601     Zimbabwe  1994     3263.934978
# 6602     Zimbabwe  1993     3033.504852
# 6603     Zimbabwe  1992     3054.889178
# 6604     Zimbabwe  1991     3426.598094
# 6605     Zimbabwe  1990     3324.348171
#
# [6606 rows x 3 columns]

# %% [markdown]
# 12. Change the columns for the Internet Users DataFrame to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’.

# %%
internet_df = internet_df.rename(columns={'Country or Area': 'Country','Year':'Year','Value':'Internet_Users_Pct'})

internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# 13. Merge the two DataFrames to one. Merge all rows from each of the two DataFrames. Call the new DataFrame gdp_and_internet_use.
#
# 14. Look at the first five rows of your new DataFrame to confirm it merged correctly.
# 15. Look at the last five rows to make sure the data is clean and as expected.

# %%
gdp_and_internet_use = gdp_df.merge(internet_df, how='outer', on=['Country', 'Year'])
gdp_and_internet_use.head(5)
gdp_and_internet_use
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2018     2190.240321                 NaN
# 1     Afghanistan  2017     2202.570851                 NaN
# 2     Afghanistan  2016     2200.764487                 NaN
# 3     Afghanistan  2015     2212.750899                 NaN
# 4     Afghanistan  2014     2249.253738            6.390000
# ...           ...   ...             ...                 ...
# 7659        Yemen  1999             NaN            0.056629
# 7660        Yemen  1998             NaN            0.023323
# 7661        Yemen  1997             NaN            0.015025
# 7662        Yemen  1996             NaN            0.000621
# 7663        Yemen  1990             NaN            0.000000
#
# [7664 rows x 4 columns]

# %% [markdown]
# 16. Subset the combined DataFrame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
combo= gdp_and_internet_use[(gdp_and_internet_use.Year == '2004') | (gdp_and_internet_use.Year == '2009') | (gdp_and_internet_use.Year == '2019')]
combo
# Out:
# Empty DataFrame
# Columns: [Country, Year, GDP_Per_Capita, Internet_Users_Pct]
# Index: []

# %% [markdown]
# 17. Create three new DataFrames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long.

# %%
year_2004 = gdp_and_internet_use[(gdp_and_internet_use.Year == 2004)]
year_2009 = gdp_and_internet_use[(gdp_and_internet_use.Year == 2009)]
year_2014 = gdp_and_internet_use[(gdp_and_internet_use.Year == 2014)]

# %%
year_2004
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 14              Afghanistan  2004     1284.127338            0.105809
# 31                  Albania  2004     7738.542836            2.420388
# 60                  Algeria  2004     9898.310490            4.634475
# 89                   Angola  2004     5568.959139            0.464815
# 118     Antigua and Barbuda  2004    18742.463741           24.266544
# ...                     ...   ...             ...                 ...
# 7530     T.F.Y.R. Macedonia  2004             NaN           24.440000
# 7588              Venezuela  2004             NaN            8.404470
# 7612               Viet Nam  2004             NaN            7.642409
# 7632  Virgin Islands (U.S.)  2004             NaN           27.377009
# 7654                  Yemen  2004             NaN            0.881223
#
# [276 rows x 4 columns]

# %%
year_2009
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 9               Afghanistan  2009     1881.777626             3.55000
# 26                  Albania  2009    10528.778102            41.20000
# 55                  Algeria  2009    10610.711405            11.23000
# 84                   Angola  2009     7610.310423             6.00000
# 113     Antigua and Barbuda  2009    19989.092913            42.00000
# ...                     ...   ...             ...                 ...
# 7525     T.F.Y.R. Macedonia  2009             NaN            51.77000
# 7583              Venezuela  2009             NaN            32.70000
# 7607               Viet Nam  2009             NaN            26.55000
# 7627  Virgin Islands (U.S.)  2009             NaN            27.39651
# 7649                  Yemen  2009             NaN             9.96000
#
# [277 rows x 4 columns]

# %%
year_2014
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4               Afghanistan  2014     2249.253738                6.39
# 21                  Albania  2014    11828.232264               60.10
# 50                  Algeria  2014    11329.428688               18.09
# 79                   Angola  2014     8239.832077               21.26
# 108     Antigua and Barbuda  2014    18104.241470               64.00
# ...                     ...   ...             ...                 ...
# 7520     T.F.Y.R. Macedonia  2014             NaN               68.06
# 7578              Venezuela  2014             NaN               57.00
# 7602               Viet Nam  2014             NaN               48.31
# 7622  Virgin Islands (U.S.)  2014             NaN               50.07
# 7644                  Yemen  2014             NaN               22.55
#
# [277 rows x 4 columns]

# %% [markdown]
# 18. Which country had the highest percentage of internet users in 2014? What was the percentage? (Try typing the first 3 letters of your DataFrame name and hitting the tab key for auto-complete options).

# %%
year_2014 = year_2014.astype({"Internet_Users_Pct": float})
year_2014.sort_values("Internet_Users_Pct", ascending = False)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2507              Iceland  2014    49911.069825               98.16
# 6649              Bermuda  2014             NaN               96.80
# 4461               Norway  2014    61308.763730               96.30
# 1374              Denmark  2014    52172.606425               95.99
# 6609              Andorra  2014             NaN               95.90
# ...                   ...   ...             ...                 ...
# 6179               Tuvalu  2014     3455.741510                 NaN
# 6353  Upper middle income  2014    14271.692393                 NaN
# 6469              Vietnam  2014     6098.489609                 NaN
# 6498   West Bank and Gaza  2014     5499.415939                 NaN
# 6523                World  2014    15181.246955                 NaN
#
# [277 rows x 4 columns]

# %% [markdown]
# 19. Which country had the lowest percentage of internet users in 2014? What was the percentage?

# %%
year_2014 = year_2014.astype({"Internet_Users_Pct": float})
year_2014.sort_values("Internet_Users_Pct", ascending = True)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6838  Dem. People's Rep. of Korea  2014             NaN                0.00
# 6896                      Eritrea  2014             NaN                0.99
# 5978                  Timor-Leste  2014     3264.739189                1.14
# 770                       Burundi  2014      886.235777                1.38
# 7433                      Somalia  2014             NaN                1.63
# ...                           ...   ...             ...                 ...
# 6179                       Tuvalu  2014     3455.741510                 NaN
# 6353          Upper middle income  2014    14271.692393                 NaN
# 6469                      Vietnam  2014     6098.489609                 NaN
# 6498           West Bank and Gaza  2014     5499.415939                 NaN
# 6523                        World  2014    15181.246955                 NaN
#
# [277 rows x 4 columns]

# %% [markdown]
# 20. Repeat for 2004 and 2009.

# %%
year_2004 = year_2004.astype({"Internet_Users_Pct": float})
year_2004.sort_values("Internet_Users_Pct", ascending = False)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5785               Sweden  2004    45029.814344               83.89
# 2517              Iceland  2004    45380.965464               83.88
# 1384              Denmark  2004    50566.988088               80.93
# 4471               Norway  2004    59647.501415               77.69
# 7159      Korea (Rep. of)  2004             NaN               72.70
# ...                   ...   ...             ...                 ...
# 6189               Tuvalu  2004     3341.738017                 NaN
# 6363  Upper middle income  2004     8561.878030                 NaN
# 6479              Vietnam  2004     3689.732423                 NaN
# 6508   West Bank and Gaza  2004     4113.246936                 NaN
# 6533                World  2004    12070.457345                 NaN
#
# [276 rows x 4 columns]

# %%
year_2004 = year_2004.astype({"Internet_Users_Pct": float})
year_2004.sort_values("Internet_Users_Pct", ascending = True)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6847  Dem. People's Rep. of Korea  2004             NaN            0.000000
# 4166                      Myanmar  2004     1696.881760            0.024337
# 3395                      Liberia  2004     1181.546158            0.031011
# 5843                   Tajikistan  2004     1737.743630            0.077480
# 14                    Afghanistan  2004     1284.127338            0.105809
# ...                           ...   ...             ...                 ...
# 6189                       Tuvalu  2004     3341.738017                 NaN
# 6363          Upper middle income  2004     8561.878030                 NaN
# 6479                      Vietnam  2004     3689.732423                 NaN
# 6508           West Bank and Gaza  2004     4113.246936                 NaN
# 6533                        World  2004    12070.457345                 NaN
#
# [276 rows x 4 columns]

# %%
year_2009 = year_2009.astype({"Internet_Users_Pct": float})
year_2009.sort_values("Internet_Users_Pct", ascending = False)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2512              Iceland  2009    48428.312438               93.00
# 4466               Norway  2009    60620.334503               92.08
# 5780               Sweden  2009    46185.526525               91.00
# 4263          Netherlands  2009    51850.500537               89.63
# 3540           Luxembourg  2009   105077.951508               87.31
# ...                   ...   ...             ...                 ...
# 5954           The Gambia  2009     2283.183556                 NaN
# 6358  Upper middle income  2009    11209.044717                 NaN
# 6474              Vietnam  2009     4830.304958                 NaN
# 6503   West Bank and Gaza  2009     4721.086034                 NaN
# 6528                World  2009    13389.627693                 NaN
#
# [277 rows x 4 columns]

# %%
year_2009 = year_2009.astype({"Internet_Users_Pct": float})
year_2009.sort_values("Internet_Users_Pct", ascending = True)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6842  Dem. People's Rep. of Korea  2009             NaN            0.000000
# 5983                  Timor-Leste  2009     2724.834868            0.185252
# 4161                      Myanmar  2009     2874.780227            0.220000
# 5225                 Sierra Leone  2009     1372.392285            0.260000
# 862                      Cambodia  2009     2603.583778            0.530000
# ...                           ...   ...             ...                 ...
# 5954                   The Gambia  2009     2283.183556                 NaN
# 6358          Upper middle income  2009    11209.044717                 NaN
# 6474                      Vietnam  2009     4830.304958                 NaN
# 6503           West Bank and Gaza  2009     4721.086034                 NaN
# 6528                        World  2009    13389.627693                 NaN
#
# [277 rows x 4 columns]

# %% [markdown]
# another way
# max_2004[max_2004['Internet_Users_Pct']==gmax__2004['Internet_Users_Pct'].max()]
# year_2004[year_2004['Internet_Users_Pct']==year_2004['Internet_Users_Pct'].max()

# %% [markdown]
# 21. Which country had the highest gdp per capita in 2014? What was the gdp per capita?

# %%
year_2014 = year_2014.astype({"GDP_Per_Capita": float})
year_2014.sort_values("GDP_Per_Capita", ascending = False)
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3564       Macao SAR, China  2014   156514.133850                 NaN
# 3535             Luxembourg  2014   108911.348894               94.67
# 4934                  Qatar  2014    97938.305225               91.49
# 5249              Singapore  2014    87808.663157               82.00
# 970          Cayman Islands  2014    66195.475587               74.10
# ...                     ...   ...             ...                 ...
# 7520     T.F.Y.R. Macedonia  2014             NaN               68.06
# 7578              Venezuela  2014             NaN               57.00
# 7602               Viet Nam  2014             NaN               48.31
# 7622  Virgin Islands (U.S.)  2014             NaN               50.07
# 7644                  Yemen  2014             NaN               22.55
#
# [277 rows x 4 columns]

# %% [markdown]
# 22. Which country had the lowest gdp per capita in 2014? What was the gdp per capita?

# %%
year_2014 = year_2014.astype({"GDP_Per_Capita": float})
year_2014.sort_values("GDP_Per_Capita", ascending = True)
# Out:
#                        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 983   Central African Republic  2014      822.610458                 NaN
# 770                    Burundi  2014      886.235777                1.38
# 3622                    Malawi  2014     1027.208496                5.83
# 1345           Dem. Rep. Congo  2014     1029.790785                 NaN
# 4345                     Niger  2014     1126.153622                1.95
# ...                        ...   ...             ...                 ...
# 7520        T.F.Y.R. Macedonia  2014             NaN               68.06
# 7578                 Venezuela  2014             NaN               57.00
# 7602                  Viet Nam  2014             NaN               48.31
# 7622     Virgin Islands (U.S.)  2014             NaN               50.07
# 7644                     Yemen  2014             NaN               22.55
#
# [277 rows x 4 columns]

# %% [markdown]
# 23. Create some scatterplots:
# a. 2004 Percent Using the Internet vs GDP Per Capita
# b. 2009 Percent Using the Internet vs GDP Per Capita
# c. 2014 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(year_2014.Internet_Users_Pct, year_2014.GDP_Per_Capita)
plt.title("Year_2014")
plt.xlabel("Internet_Users_Pct")
plt.ylabel("GDP_Per_Capita")
# Out:
# Text(0, 0.5, 'GDP_Per_Capita')

# %%
plt.scatter(year_2009.Internet_Users_Pct, year_2009.GDP_Per_Capita)
plt.title("Year_2009")
plt.xlabel("Internet_Users_Pct")
plt.ylabel("GDP_Per_Capita")
# Out:
# Text(0, 0.5, 'GDP_Per_Capita')

# %%
plt.scatter(year_2004.Internet_Users_Pct, year_2004.GDP_Per_Capita)
plt.title("Year_2004")
plt.xlabel("Internet_Users_Pct")
plt.ylabel("GDP_Per_Capita")
# Out:
# Text(0, 0.5, 'GDP_Per_Capita')

# %%
gdp_df.info()
gdp_df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6606 entries, 0 to 6605
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         6606 non-null   object
#  1   Year            6606 non-null   int64
#  2   GDP_Per_Capita  6606 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 155.0+ KB
#        Country  Year  GDP_Per_Capita
# 6601  Zimbabwe  1994     3263.934978
# 6602  Zimbabwe  1993     3033.504852
# 6603  Zimbabwe  1992     3054.889178
# 6604  Zimbabwe  1991     3426.598094
# 6605  Zimbabwe  1990     3324.348171

# %% [markdown]
# 24. Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.

# %% [markdown]
# Yes, for the most part countries with higer GDP per capita have higher internet usages.

# %% [markdown]
# 25. Look at the distribution of gdp per capita values for 2014. Is it unimodal?

# %%
plt.hist(year_2014.GDP_Per_Capita)
# Out:
# (array([146.,  41.,  24.,  19.,   3.,   1.,   2.,   0.,   0.,   1.]),
#  array([   822.61045782,  16391.76279701,  31960.91513621,  47530.06747541,
#          63099.2198146 ,  78668.3721538 ,  94237.524493  , 109806.67683219,
#         125375.82917139, 140944.98151059, 156514.13384978]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Yes, there is a clear peak - unimodal distribution

# %% [markdown]
# 26. Look at the distribution of Internet Use for 2014. Is it unimodal?

# %%
plt.hist(year_2014.Internet_Users_Pct)
# Out:
# (array([31., 31., 12., 10., 24., 18., 21., 20., 18., 17.]),
#  array([ 0.   ,  9.816, 19.632, 29.448, 39.264, 49.08 , 58.896, 68.712,
#         78.528, 88.344, 98.16 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# No, there is no clear pleak- distribution

# %% [markdown]
# 27. What are the top 5 countries in terms of internet use in 2014?

# %%
top_five = year_2014.sort_values("Internet_Users_Pct", ascending = False)
top_five.head()
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2507  Iceland  2014    49911.069825               98.16
# 6649  Bermuda  2014             NaN               96.80
# 4461   Norway  2014    61308.763730               96.30
# 1374  Denmark  2014    52172.606425               95.99
# 6609  Andorra  2014             NaN               95.90

# %% [markdown]
# 28. Create a DataFrame called top_5_internet from the combined DataFrame that has all three years for the 5 countries that had the greatest 2014 internet usage. You should have 15 rows. Check that this is true.

# %%
filtered_years = gdp_and_internet_use[(gdp_and_internet_use.Year == 2004 or gdp_and_internet_use.Year == 2009 or gdp_and_internet_use.Year == 2014)]
filtered_years
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-e4f613952818> in <module>
# ----> 1 filtered_years = gdp_and_internet_use[(gdp_and_internet_use.Year == 2004 or gdp_and_internet_use.Year == 2009 or gdp_and_internet_use.Year ==2014)]
#       2 filtered_years
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#top_5_internet=(filtered_years.loc[filtered_years['Country'].isin(['Iceland', 'Bermuda','Norway','Denmark','Andorra'])])
top_5_internet=(filtered_years.loc[filtered_years['Country'].isin([top_five])])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-a65015c725ef> in <module>
# ----> 1 top_5_internet=(filtered_years.loc[filtered_years['Country'].isin([top_five])])
#
# NameError: name 'filtered_years' is not defined
